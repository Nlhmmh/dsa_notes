# %%
import unittest

# %%
# Bubble Sort
# Time: O(n^2) in worst case, O(n) in best case
# Space: O(1)

def bubble_sort(arr):
    for i in range(len(arr)):
        isSwapped = False
        print(f"Pass {i+1}: {arr}")
        for j in range(0, len(arr)-1-i):
            print(f"Comparing {arr[j]} and {arr[j+1]}")
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                isSwapped = True
        if not isSwapped:
            break;
    return arr

class TestBubbleSort(unittest.TestCase):
    def test_bubble_sort(self):
        self.assertEqual(bubble_sort([2, 1, 3, 7, 6]), [1, 2, 3, 6, 7])
        self.assertEqual(bubble_sort([5, 4, 3, 2, 1]), [1, 2, 3, 4, 5])
        self.assertEqual(bubble_sort([]), [])
        self.assertEqual(bubble_sort([1]), [1])
        self.assertEqual(bubble_sort([1, 2]), [1, 2])
        self.assertEqual(bubble_sort([2, 1]), [1, 2])

unittest.main(argv=[''], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# Pass 1: [2, 1, 3, 7, 6]
# Comparing 2 and 1
# Comparing 2 and 3
# Comparing 3 and 7
# Comparing 7 and 6
# Pass 2: [1, 2, 3, 6, 7]
# Comparing 1 and 2
# Comparing 2 and 3
# Comparing 3 and 6
# Pass 1: [5, 4, 3, 2, 1]
# Comparing 5 and 4
# Comparing 5 and 3
# Comparing 5 and 2
# Comparing 5 and 1
# Pass 2: [4, 3, 2, 1, 5]
# Comparing 4 and 3
# Comparing 4 and 2
# Comparing 4 and 1
# Pass 3: [3, 2, 1, 4, 5]
# Comparing 3 and 2
# Comparing 3 and 1
# Pass 4: [2, 1, 3, 4, 5]
# Comparing 2 and 1
# Pass 5: [1, 2, 3, 4, 5]
# Pass 1: [1]
# Pass 1: [1, 2]
# Comparing 1 and 2
# Pass 1: [2, 1]
# Comparing 2 and 1
# Pass 2: [1, 2]
